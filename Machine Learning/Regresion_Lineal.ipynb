# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoGuedesDP/IA/blob/main/Machine%20Learning/Regresion_Lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![rl.PNG](data:image/png;base64,...)

# %%
#Clase 2
import numpy as np

#regresion lineal
def train():
  w = np.random()
  b = random
# Out:
#   File "<ipython-input-1-d50fbf8f689b>", line 6
#     w= np.
#           ^
# SyntaxError: invalid syntax
